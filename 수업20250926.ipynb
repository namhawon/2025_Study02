# %% [markdown]
# <a href="https://colab.research.google.com/github/namhawon/2025_Study02/blob/main/%EC%88%98%EC%97%8520250926.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = int(input("점수(0~100점)를 입력하세요: "))

if score >= 90:
  print("A")
elif score >= 70:
  print("B")
elif score >= 60:
  print("C")
else:
  print("D")
# Out:
# 점수(0~100점)를 입력하세요: 80
# B

# %%
sum=0
for a in range(1,101):
  sum = sum + a

  print("1부터 100까지의 합은", sum ,'입니다.')
# Out:
# 1부터 100까지의 합은 1 입니다.
# 1부터 100까지의 합은 3 입니다.
# 1부터 100까지의 합은 6 입니다.
# 1부터 100까지의 합은 10 입니다.
# 1부터 100까지의 합은 15 입니다.
# 1부터 100까지의 합은 21 입니다.
# 1부터 100까지의 합은 28 입니다.
# 1부터 100까지의 합은 36 입니다.
# 1부터 100까지의 합은 45 입니다.
# 1부터 100까지의 합은 55 입니다.
# 1부터 100까지의 합은 66 입니다.
# 1부터 100까지의 합은 78 입니다.
# 1부터 100까지의 합은 91 입니다.
# 1부터 100까지의 합은 105 입니다.
# 1부터 100까지의 합은 120 입니다.
# 1부터 100까지의 합은 136 입니다.
# 1부터 100까지의 합은 153 입니다.
# 1부터 100까지의 합은 171 입니다.
# 1부터 100까지의 합은 190 입니다.
# 1부터 100까지의 합은 210 입니다.
# 1부터 100까지의 합은 231 입니다.
# 1부터 100까지의 합은 253 입니다.
# 1부터 100까지의 합은 276 입니다.
# 1부터 100까지의 합은 300 입니다.
# 1부터 100까지의 합은 325 입니다.
# 1부터 100까지의 합은 351 입니다.
# 1부터 100까지의 합은 378 입니다.
# 1부터 100까지의 합은 406 입니다.
# 1부터 100까지의 합은 435 입니다.
# 1부터 100까지의 합은 465 입니다.
# 1부터 100까지의 합은 496 입니다.
# 1부터 100까지의 합은 528 입니다.
# 1부터 100까지의 합은 561 입니다.
# 1부터 100까지의 합은 595 입니다.
# 1부터 100까지의 합은 630 입니다.
# 1부터 100까지의 합은 666 입니다.
# 1부터 100까지의 합은 703 입니다.
# 1부터 100까지의 합은 741 입니다.
# 1부터 100까지의 합은 780 입니다.
# 1부터 100까지의 합은 820 입니다.
# ...

# %%
money = 0
day = 0
while sum < 50000:
  sum = sum + money
  money = money + 100
  day = day + 1

print("총", day, "일이 걸립니다.")
# Out:
# 총 0 일이 걸립니다.

# %%
sum = 0
money = 100
day =1

while sum < 50000:
  sum = sum + money
  money = money + 100
  day = day + 1

print("총", day, "일이 걸립니다.")
# Out:
# 총 33 일이 걸립니다.

# %%
total_sum = 0

while True:
  num = int(input("숫자를 입력하세요 (0을 입력하면 종료): "))
  if num == 0:
    break
  total_sum += num

print("최종 총합:", total_sum)
# Out:
# 숫자를 입력하세요 (0을 입력하면 종료): 5
# 숫자를 입력하세요 (0을 입력하면 종료): 3
# 숫자를 입력하세요 (0을 입력하면 종료): 10
# 숫자를 입력하세요 (0을 입력하면 종료): 9
# 숫자를 입력하세요 (0을 입력하면 종료): 7
# 숫자를 입력하세요 (0을 입력하면 종료): 0
# 최종 총합: 34
